# %%
# %load_ext autoreload
# %autoreload 2

from roomgraph.data.etl import generate_graph
from pathlib import Path
import networkx as nx

# %%
data_dir = Path('../data/raw/cubicasa5k/')
plan_dirs = list(data_dir.glob('**/model.svg'))

# %%
graph, labels = generate_graph(plan_dirs[0])
nx.draw(graph, labels=labels.name)

# %%
labels.plot(column='name', legend=True)
# Out:
# <AxesSubplot: >
