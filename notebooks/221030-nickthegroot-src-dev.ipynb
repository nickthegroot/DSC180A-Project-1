# %%
# %load_ext autoreload
# %autoreload 2

from roomgraph.data.etl import generate_graph
from pathlib import Path
import networkx as nx

# %%
data_dir = Path('../data/raw/cubicasa5k/')
plan_dirs = list(data_dir.glob('**/model.svg'))

# %%
graph = generate_graph(plan_dirs[0])
nx.draw_networkx(
    graph,
    labels={ key: val['space'] for key, val in graph.nodes.items() },
)
